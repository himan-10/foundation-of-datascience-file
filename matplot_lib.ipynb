# %% [markdown]
# <a href="https://colab.research.google.com/github/himan-10/pandasfile/blob/main/matplot_lib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1.Write a Python program to draw a line using given axis values taken
# from a text file, with suitable label in the x axis, y axis and a title.
# Test Data:
# test.txt
# 1 2
# 2 4
# 3 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=[1,2,3]
y=[2,4,1]
plt.plot(x,y)
plt.xlable("number in horizental line : ", fontsize=20);
plt.ylable("number in vertical line : ", fontsize=20);
plt.table("line graph", fontsize=2.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-1165267fc69f> in <cell line: 7>()
#       5 y=[2,4,1]
#       6 plt.plot(x,y)
# ----> 7 plt.xlable("number in horizental line : ", fontsize=20);
#       8 plt.ylable("number in vertical line : ", fontsize=20);
#       9 plt.table("line graph", fontsize=2.3)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %% [markdown]
#  Q2. Write a Python program to draw line charts of the financial data of
# Alphabet Inc. between October 3, 2016 to October 7, 2016.
# Sample Financial data (fdata.csv):
# Date, Open, High, Low, Close
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample financial data
data = {
    'Date': ['10-03-16', '10-04-16', '10-05-16', '10-06-16', '10-07-16'],
    'Open': [774.25, 776.030029, 779.309998, 779, 779.659973],
    'High': [776.065002, 778.710022, 782.070007, 780.47998, 779.659973],
    'Low': [769.5, 772.890015, 775.650024, 775.539978, 770.75],
    'Close': [772.559998, 776.429993, 776.469971, 776.859985, 775.080017]
}

# Convert the sample data to a DataFrame
df = pd.DataFrame(data)

# Convert the 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')

# Filter the DataFrame to get data between October 3, 2016, and October 7, 2016
start_date = '2016-10-03'
end_date = '2016-10-07'
filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

# Plotting the line chart
plt.figure(figsize=(10, 6))
plt.plot(filtered_df['Date'], filtered_df['Close'], marker='o', linestyle='-')
plt.title('Alphabet Inc. Closing Prices (Oct 3-7, 2016)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Write a Python program to plot two or more lines with different styles.
# The code snippet gives the output shown in the following screenshot:
